# %%
import findspark
findspark.init()
from pyspark import SparkContext
sc = SparkContext("local[*]","search-data")

# %%
inputFile = sc.textFile("file:///E:/abhishek/pyspark-projects/datasets/customerorders.csv")

# %%
tus = inputFile.map(lambda x: )

# %%
total_cont = mapped.reduceByKey(lambda x,y: (x+y)).map(lambda x:(x[1],x[0]))

# %%
answer = total_cont.sortByKey(False).map(lambda x:(x[1],x[0])).collect()

# %%
for a in answer:
    print(a)
# Out:
# ('data', 361)
# ('big', 285)
# ('in', 171)
# ('training', 114)
# ('course', 105)
# ('hadoop', 100)
# ('online', 58)
# ('courses', 53)
# ('spark', 42)
# ('bangalore', 40)
# ('analytics', 35)
# ('hyderabad', 33)
# ('for', 30)
# ('best', 29)
# ('of', 27)
# ('certification', 26)
# ('and', 22)
# ('to', 21)
# ('with', 21)
# ('bigdata', 20)
# ('chennai', 20)
# ('institute', 19)
# ('india', 16)
# ('apache', 15)
# ('learn', 15)
# ('tutorial', 15)
# ('is', 12)
# ('learning', 12)
# ('institutes', 12)
# ('the', 12)
# ('analyst', 11)
# ('scala', 11)
# ('placement', 11)
# ('classes', 11)
# ('edureka', 11)
# ('python', 10)
# ('intellipaat', 10)
# ('fees', 10)
# ('iit', 10)
# ('delhi', 9)
# ('engineering', 9)
# ('engineer', 9)
# ('coursera', 9)
# ('by', 9)
# ('fee', 8)
# ('top', 8)
# ('from', 8)
# ('which', 8)
# ('pune', 8)
# ('pg', 7)
# ('simplilearn', 7)
# ('program', 7)
# ('on', 7)
# ('architect', 7)
# ('class', 6)
# ('coaching', 6)
# ('ameerpet', 6)
# ('near', 6)
# ('cloudera', 6)
# ...
